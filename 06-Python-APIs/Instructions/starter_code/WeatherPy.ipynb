# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL

query_url = f"{url}appid={api_key}&units={units}&q="

city_name = []

cloudiness = []

country = []

date = []

humidity = []

lat = []

lng = []

max_temp = []

wind_speed = []

# Counter

count = 0

print("Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through all the cities in the city list 

for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        count = count + 1;
        
        # Print city output
        print(f"Processing Record {count} | {city_record}")
        print(f"{url}&q={city}")
        
        # time to wait 
        time.sleep(1.1)
 
        
    # City Not Found
    except KeyError:
        
        print("City not found")

print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 2 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 3 | Chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 4 | Flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 5 | Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 6 | Mosquera
# http://api.openweathermap.org/data/2.5/weather?&q=mosquera
# Processing Record 7 | Ouadda
# http://api.openweathermap.org/data/2.5/weather?&q=ouadda
# Processing Record 8 | Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 9 | Victoria
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 10 | Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 11 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 12 | Ossora
# http://api.openweathermap.org/data/2.5/weather?&q=ossora
# Processing Record 13 | Vilhena
# http://api.openweathermap.org/data/2.5/weather?&q=vilhena
# Processing Record 14 | Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 15 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 16 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# City not found
# Processing Record 17 | East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# City not found
# Processing Record 18 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?&q=mabaruma
# Processing Record 19 | Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 20 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 21 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 22 | Cravo Norte
# http://api.openweathermap.org/data/2.5/weather?&q=cravo norte
# Processing Record 23 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?&q=hobyo
# Processing Record 24 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 25 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# City not found
# Processing Record 26 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 27 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 28 | Bone
# http://api.openweathermap.org/data/2.5/weather?&q=bone
# Processing Record 29 | Lahij
# http://api.openweathermap.org/data/2.5/weather?&q=lahij
# Processing Record 30 | Rongcheng
# http://api.openweathermap.org/data/2.5/weather?&q=rongcheng
# Processing Record 31 | Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 32 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 33 | Mersin
# http://api.openweathermap.org/data/2.5/weather?&q=mersin
# Processing Record 34 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 35 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 36 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 37 | Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 38 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?&q=mount isa
# Processing Record 39 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 40 | Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 41 | Gari
# http://api.openweathermap.org/data/2.5/weather?&q=gari
# Processing Record 42 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 43 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?&q=tessalit
# Processing Record 44 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 45 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# City not found
# Processing Record 46 | Chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 47 | Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 48 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?&q=henties bay
# Processing Record 49 | Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 50 | Iisalmi
# http://api.openweathermap.org/data/2.5/weather?&q=iisalmi
# Processing Record 51 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?&q=abu kamal
# Processing Record 52 | Muros
# http://api.openweathermap.org/data/2.5/weather?&q=muros
# Processing Record 53 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# City not found
# Processing Record 54 | Guiratinga
# http://api.openweathermap.org/data/2.5/weather?&q=guiratinga
# Processing Record 55 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 56 | Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 57 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 58 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 59 | Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 60 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# City not found
# Processing Record 61 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# City not found
# City not found
# Processing Record 62 | Bom Sucesso
# http://api.openweathermap.org/data/2.5/weather?&q=bom sucesso
# Processing Record 63 | Novikovo
# http://api.openweathermap.org/data/2.5/weather?&q=novikovo
# City not found
# Processing Record 64 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 65 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# Processing Record 66 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 67 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 68 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 69 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?&q=bay roberts
# Processing Record 70 | Kumano
# http://api.openweathermap.org/data/2.5/weather?&q=kumano
# Processing Record 71 | Xucheng
# http://api.openweathermap.org/data/2.5/weather?&q=xucheng
# Processing Record 72 | Emba
# http://api.openweathermap.org/data/2.5/weather?&q=emba
# City not found
# Processing Record 73 | Tvoroyri
# http://api.openweathermap.org/data/2.5/weather?&q=tvoroyri
# Processing Record 74 | Hami
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# City not found
# Processing Record 75 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 76 | Poronaysk
# http://api.openweathermap.org/data/2.5/weather?&q=poronaysk
# Processing Record 77 | Neijiang
# http://api.openweathermap.org/data/2.5/weather?&q=neijiang
# Processing Record 78 | Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 79 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?&q=aykhal
# Processing Record 80 | Lieksa
# http://api.openweathermap.org/data/2.5/weather?&q=lieksa
# Processing Record 81 | Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 82 | Yaan
# http://api.openweathermap.org/data/2.5/weather?&q=yaan
# Processing Record 83 | Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 84 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 85 | Borovskoy
# http://api.openweathermap.org/data/2.5/weather?&q=borovskoy
# Processing Record 86 | Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 87 | Korem
# http://api.openweathermap.org/data/2.5/weather?&q=korem
# Processing Record 88 | Prinos
# http://api.openweathermap.org/data/2.5/weather?&q=prinos
# Processing Record 89 | Iquitos
# http://api.openweathermap.org/data/2.5/weather?&q=iquitos
# Processing Record 90 | Orotukan
# http://api.openweathermap.org/data/2.5/weather?&q=orotukan
# Processing Record 91 | Smithers
# http://api.openweathermap.org/data/2.5/weather?&q=smithers
# Processing Record 92 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 93 | Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# City not found
# Processing Record 94 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 95 | Pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 96 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 97 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 98 | Nolinsk
# http://api.openweathermap.org/data/2.5/weather?&q=nolinsk
# Processing Record 99 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 100 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?&q=nyurba
# Processing Record 101 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?&q=yerbogachen
# Processing Record 102 | Tijucas
# http://api.openweathermap.org/data/2.5/weather?&q=tijucas
# Processing Record 103 | Nayoro
# http://api.openweathermap.org/data/2.5/weather?&q=nayoro
# Processing Record 104 | Yarada
# http://api.openweathermap.org/data/2.5/weather?&q=yarada
# City not found
# Processing Record 105 | Soubre
# http://api.openweathermap.org/data/2.5/weather?&q=soubre
# Processing Record 106 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 107 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 108 | Sunggal
# http://api.openweathermap.org/data/2.5/weather?&q=sunggal
# Processing Record 109 | Aldan
# http://api.openweathermap.org/data/2.5/weather?&q=aldan
# Processing Record 110 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 111 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?&q=dudinka
# Processing Record 112 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 113 | Mamburao
# http://api.openweathermap.org/data/2.5/weather?&q=mamburao
# Processing Record 114 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?&q=hervey bay
# Processing Record 115 | Bilma
# http://api.openweathermap.org/data/2.5/weather?&q=bilma
# Processing Record 116 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?&q=clarence town
# Processing Record 117 | Menongue
# http://api.openweathermap.org/data/2.5/weather?&q=menongue
# Processing Record 118 | Monster
# http://api.openweathermap.org/data/2.5/weather?&q=monster
# Processing Record 119 | Kopargaon
# http://api.openweathermap.org/data/2.5/weather?&q=kopargaon
# Processing Record 120 | Marihatag
# http://api.openweathermap.org/data/2.5/weather?&q=marihatag
# City not found
# City not found
# Processing Record 121 | Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 122 | Launceston
# http://api.openweathermap.org/data/2.5/weather?&q=launceston
# Processing Record 123 | Lumphat
# http://api.openweathermap.org/data/2.5/weather?&q=lumphat
# Processing Record 124 | Miri
# http://api.openweathermap.org/data/2.5/weather?&q=miri
# Processing Record 125 | Broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 126 | Hobbs
# http://api.openweathermap.org/data/2.5/weather?&q=hobbs
# Processing Record 127 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 128 | Give
# http://api.openweathermap.org/data/2.5/weather?&q=give
# Processing Record 129 | Dzhebariki-Khaya
# http://api.openweathermap.org/data/2.5/weather?&q=dzhebariki-khaya
# Processing Record 130 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?&q=mizdah
# Processing Record 131 | Camopi
# http://api.openweathermap.org/data/2.5/weather?&q=camopi
# Processing Record 132 | Husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 133 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?&q=marsh harbour
# Processing Record 134 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 135 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 136 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 137 | Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 138 | Riverton
# http://api.openweathermap.org/data/2.5/weather?&q=riverton
# Processing Record 139 | Buala
# http://api.openweathermap.org/data/2.5/weather?&q=buala
# Processing Record 140 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 141 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?&q=kasongo-lunda
# Processing Record 142 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 143 | Kathu
# http://api.openweathermap.org/data/2.5/weather?&q=kathu
# Processing Record 144 | Weifang
# http://api.openweathermap.org/data/2.5/weather?&q=weifang
# Processing Record 145 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# City not found
# Processing Record 146 | Vrnjacka Banja
# http://api.openweathermap.org/data/2.5/weather?&q=vrnjacka banja
# Processing Record 147 | Merauke
# http://api.openweathermap.org/data/2.5/weather?&q=merauke
# Processing Record 148 | Conakry
# http://api.openweathermap.org/data/2.5/weather?&q=conakry
# Processing Record 149 | Kolpashevo
# http://api.openweathermap.org/data/2.5/weather?&q=kolpashevo
# Processing Record 150 | Aliwal North
# http://api.openweathermap.org/data/2.5/weather?&q=aliwal north
# Processing Record 151 | Betong
# http://api.openweathermap.org/data/2.5/weather?&q=betong
# Processing Record 152 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# City not found
# Processing Record 153 | Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 154 | Hit
# http://api.openweathermap.org/data/2.5/weather?&q=hit
# Processing Record 155 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 156 | Marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?&q=marsaxlokk
# Processing Record 157 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 158 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 159 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 160 | Abnub
# http://api.openweathermap.org/data/2.5/weather?&q=abnub
# City not found
# Processing Record 161 | Koungheul
# http://api.openweathermap.org/data/2.5/weather?&q=koungheul
# Processing Record 162 | Horasan
# http://api.openweathermap.org/data/2.5/weather?&q=horasan
# Processing Record 163 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 164 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 165 | Salisbury
# http://api.openweathermap.org/data/2.5/weather?&q=salisbury
# Processing Record 166 | Obigarm
# http://api.openweathermap.org/data/2.5/weather?&q=obigarm
# Processing Record 167 | Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 168 | Zhaodong
# http://api.openweathermap.org/data/2.5/weather?&q=zhaodong
# Processing Record 169 | George
# http://api.openweathermap.org/data/2.5/weather?&q=george
# Processing Record 170 | Mangaratiba
# http://api.openweathermap.org/data/2.5/weather?&q=mangaratiba
# Processing Record 171 | Naze
# http://api.openweathermap.org/data/2.5/weather?&q=naze
# Processing Record 172 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 173 | Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 174 | Nongan
# http://api.openweathermap.org/data/2.5/weather?&q=nongan
# City not found
# Processing Record 175 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 176 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 177 | Romny
# http://api.openweathermap.org/data/2.5/weather?&q=romny
# Processing Record 178 | Tyukhtet
# http://api.openweathermap.org/data/2.5/weather?&q=tyukhtet
# Processing Record 179 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?&q=quelimane
# Processing Record 180 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 181 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?&q=oussouye
# Processing Record 182 | Lesnoy Gorodok
# http://api.openweathermap.org/data/2.5/weather?&q=lesnoy gorodok
# Processing Record 183 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 184 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?&q=tucuman
# Processing Record 185 | Yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 186 | Chimore
# http://api.openweathermap.org/data/2.5/weather?&q=chimore
# Processing Record 187 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 188 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?&q=nouakchott
# Processing Record 189 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?&q=shelburne
# Processing Record 190 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?&q=shenjiamen
# Processing Record 191 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 192 | Jaru
# http://api.openweathermap.org/data/2.5/weather?&q=jaru
# Processing Record 193 | Victoria
# http://api.openweathermap.org/data/2.5/weather?&q=labuan
# Processing Record 194 | Brenham
# http://api.openweathermap.org/data/2.5/weather?&q=brenham
# Processing Record 195 | Killarney
# http://api.openweathermap.org/data/2.5/weather?&q=killarney
# Processing Record 196 | Mackay
# http://api.openweathermap.org/data/2.5/weather?&q=mackay
# Processing Record 197 | Mbekenyera
# http://api.openweathermap.org/data/2.5/weather?&q=mbekenyera
# Processing Record 198 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 199 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 200 | Pizarro
# http://api.openweathermap.org/data/2.5/weather?&q=pizarro
# Processing Record 201 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 202 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?&q=oranjemund
# Processing Record 203 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 204 | Sebaco
# http://api.openweathermap.org/data/2.5/weather?&q=sebaco
# Processing Record 205 | Lamu
# http://api.openweathermap.org/data/2.5/weather?&q=lamu
# Processing Record 206 | Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 207 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 208 | Dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 209 | Honningsvag
# http://api.openweathermap.org/data/2.5/weather?&q=honningsvag
# Processing Record 210 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?&q=luwuk
# Processing Record 211 | Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 212 | College
# http://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 213 | Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# Processing Record 214 | Linhai
# http://api.openweathermap.org/data/2.5/weather?&q=linhai
# Processing Record 215 | Warrington
# http://api.openweathermap.org/data/2.5/weather?&q=warrington
# Processing Record 216 | Balabac
# http://api.openweathermap.org/data/2.5/weather?&q=balabac
# Processing Record 217 | Margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 218 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?&q=porto novo
# Processing Record 219 | Sal Rei
# http://api.openweathermap.org/data/2.5/weather?&q=sal rei
# Processing Record 220 | Amuntai
# http://api.openweathermap.org/data/2.5/weather?&q=amuntai
# Processing Record 221 | Severnoye
# http://api.openweathermap.org/data/2.5/weather?&q=severnoye
# Processing Record 222 | Regeneracao
# http://api.openweathermap.org/data/2.5/weather?&q=regeneracao
# Processing Record 223 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?&q=kokopo
# Processing Record 224 | Ligayan
# http://api.openweathermap.org/data/2.5/weather?&q=ligayan
# Processing Record 225 | Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 226 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 227 | Fengxian
# http://api.openweathermap.org/data/2.5/weather?&q=fengxian
# Processing Record 228 | Along
# http://api.openweathermap.org/data/2.5/weather?&q=along
# Processing Record 229 | Mount Pleasant
# http://api.openweathermap.org/data/2.5/weather?&q=mount pleasant
# Processing Record 230 | Ivoti
# http://api.openweathermap.org/data/2.5/weather?&q=ivoti
# Processing Record 231 | Ardakan
# http://api.openweathermap.org/data/2.5/weather?&q=ardakan
# City not found
# Processing Record 232 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 233 | Abha
# http://api.openweathermap.org/data/2.5/weather?&q=abha
# City not found
# Processing Record 234 | Lake Havasu City
# http://api.openweathermap.org/data/2.5/weather?&q=lake havasu city
# Processing Record 235 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 236 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 237 | Rennes
# http://api.openweathermap.org/data/2.5/weather?&q=rennes
# Processing Record 238 | Bull Savanna
# http://api.openweathermap.org/data/2.5/weather?&q=bull savanna
# Processing Record 239 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 240 | Khorramshahr
# http://api.openweathermap.org/data/2.5/weather?&q=khorramshahr
# Processing Record 241 | Sandi
# http://api.openweathermap.org/data/2.5/weather?&q=sandi
# Processing Record 242 | Talaya
# http://api.openweathermap.org/data/2.5/weather?&q=talaya
# Processing Record 243 | Muroto
# http://api.openweathermap.org/data/2.5/weather?&q=muroto
# City not found
# Processing Record 244 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 245 | Kinablangan
# http://api.openweathermap.org/data/2.5/weather?&q=kinablangan
# Processing Record 246 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 247 | Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 248 | Arlit
# http://api.openweathermap.org/data/2.5/weather?&q=arlit
# City not found
# Processing Record 249 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 250 | Puerto Narino
# http://api.openweathermap.org/data/2.5/weather?&q=puerto narino
# Processing Record 251 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# City not found
# Processing Record 252 | Cukai
# http://api.openweathermap.org/data/2.5/weather?&q=cukai
# Processing Record 253 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 254 | Sambava
# http://api.openweathermap.org/data/2.5/weather?&q=sambava
# City not found
# City not found
# Processing Record 255 | Kostomuksha
# http://api.openweathermap.org/data/2.5/weather?&q=kostomuksha
# Processing Record 256 | Ust-Kalmanka
# http://api.openweathermap.org/data/2.5/weather?&q=ust-kalmanka
# Processing Record 257 | Kota Tinggi
# http://api.openweathermap.org/data/2.5/weather?&q=kota tinggi
# Processing Record 258 | Ayan
# http://api.openweathermap.org/data/2.5/weather?&q=ayan
# City not found
# Processing Record 259 | Odesskoye
# http://api.openweathermap.org/data/2.5/weather?&q=odesskoye
# Processing Record 260 | Daru
# http://api.openweathermap.org/data/2.5/weather?&q=daru
# City not found
# City not found
# Processing Record 261 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?&q=ulaangom
# Processing Record 262 | Yumen
# http://api.openweathermap.org/data/2.5/weather?&q=yumen
# Processing Record 263 | Galle
# http://api.openweathermap.org/data/2.5/weather?&q=galle
# City not found
# Processing Record 264 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 265 | Tacna
# http://api.openweathermap.org/data/2.5/weather?&q=tacna
# City not found
# Processing Record 266 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?&q=roebourne
# Processing Record 267 | Myski
# http://api.openweathermap.org/data/2.5/weather?&q=myski
# Processing Record 268 | Tete
# http://api.openweathermap.org/data/2.5/weather?&q=tete
# Processing Record 269 | Arrifes
# http://api.openweathermap.org/data/2.5/weather?&q=arrifes
# Processing Record 270 | San Carlos
# http://api.openweathermap.org/data/2.5/weather?&q=san carlos
# Processing Record 271 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?&q=iskateley
# Processing Record 272 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnevilyuysk
# Processing Record 273 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?&q=ust-nera
# Processing Record 274 | Urubicha
# http://api.openweathermap.org/data/2.5/weather?&q=urubicha
# Processing Record 275 | Mahanoro
# http://api.openweathermap.org/data/2.5/weather?&q=mahanoro
# Processing Record 276 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# Processing Record 277 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 278 | Atagay
# http://api.openweathermap.org/data/2.5/weather?&q=atagay
# Processing Record 279 | Noumea
# http://api.openweathermap.org/data/2.5/weather?&q=noumea
# Processing Record 280 | Aksu
# http://api.openweathermap.org/data/2.5/weather?&q=aksu
# Processing Record 281 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 282 | San Juan
# http://api.openweathermap.org/data/2.5/weather?&q=san juan
# Processing Record 283 | Nieuwpoort
# http://api.openweathermap.org/data/2.5/weather?&q=nieuwpoort
# Processing Record 284 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 285 | Harlingen
# http://api.openweathermap.org/data/2.5/weather?&q=harlingen
# Processing Record 286 | Dedovichi
# http://api.openweathermap.org/data/2.5/weather?&q=dedovichi
# Processing Record 287 | Kuryk
# http://api.openweathermap.org/data/2.5/weather?&q=kuryk
# Processing Record 288 | Cairns
# http://api.openweathermap.org/data/2.5/weather?&q=cairns
# Processing Record 289 | Teya
# http://api.openweathermap.org/data/2.5/weather?&q=teya
# Processing Record 290 | Velsk
# http://api.openweathermap.org/data/2.5/weather?&q=velsk
# Processing Record 291 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?&q=tateyama
# Processing Record 292 | Rome
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 293 | Camargo
# http://api.openweathermap.org/data/2.5/weather?&q=camargo
# City not found
# Processing Record 294 | Ila
# http://api.openweathermap.org/data/2.5/weather?&q=ila
# Processing Record 295 | Poplar Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=poplar bluff
# Processing Record 296 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 297 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?&q=ambovombe
# Processing Record 298 | Rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?&q=rudnichnyy
# Processing Record 299 | Vila
# http://api.openweathermap.org/data/2.5/weather?&q=vila
# Processing Record 300 | Constantine
# http://api.openweathermap.org/data/2.5/weather?&q=constantine
# Processing Record 301 | Zhaoyuan
# http://api.openweathermap.org/data/2.5/weather?&q=zhaoyuan
# Processing Record 302 | Minuri
# http://api.openweathermap.org/data/2.5/weather?&q=minuri
# Processing Record 303 | Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=lincoln
# City not found
# Processing Record 304 | High Rock
# http://api.openweathermap.org/data/2.5/weather?&q=high rock
# Processing Record 305 | Bloomfield
# http://api.openweathermap.org/data/2.5/weather?&q=bloomfield
# Processing Record 306 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 307 | Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 308 | Manggar
# http://api.openweathermap.org/data/2.5/weather?&q=manggar
# Processing Record 309 | Mislinja
# http://api.openweathermap.org/data/2.5/weather?&q=mislinja
# Processing Record 310 | Yanam
# http://api.openweathermap.org/data/2.5/weather?&q=yanam
# Processing Record 311 | Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 312 | Xining
# http://api.openweathermap.org/data/2.5/weather?&q=xining
# Processing Record 313 | Serdobsk
# http://api.openweathermap.org/data/2.5/weather?&q=serdobsk
# Processing Record 314 | Durban
# http://api.openweathermap.org/data/2.5/weather?&q=durban
# Processing Record 315 | Tonantins
# http://api.openweathermap.org/data/2.5/weather?&q=tonantins
# Processing Record 316 | Umred
# http://api.openweathermap.org/data/2.5/weather?&q=umred
# Processing Record 317 | Irbeyskoye
# http://api.openweathermap.org/data/2.5/weather?&q=irbeyskoye
# Processing Record 318 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?&q=santa rosa
# City not found
# Processing Record 319 | Satuk
# http://api.openweathermap.org/data/2.5/weather?&q=satuk
# City not found
# City not found
# Processing Record 320 | Ginir
# http://api.openweathermap.org/data/2.5/weather?&q=ginir
# City not found
# Processing Record 321 | Batagay
# http://api.openweathermap.org/data/2.5/weather?&q=batagay
# Processing Record 322 | Karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# City not found
# Processing Record 323 | Vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 324 | Gimbi
# http://api.openweathermap.org/data/2.5/weather?&q=gimbi
# Processing Record 325 | Tirat Karmel
# http://api.openweathermap.org/data/2.5/weather?&q=tirat karmel
# Processing Record 326 | Bom Jesus
# http://api.openweathermap.org/data/2.5/weather?&q=bom jesus
# Processing Record 327 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# City not found
# Processing Record 328 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# Processing Record 329 | Martil
# http://api.openweathermap.org/data/2.5/weather?&q=martil
# Processing Record 330 | Quezon
# http://api.openweathermap.org/data/2.5/weather?&q=quezon
# Processing Record 331 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 332 | Kutahya
# http://api.openweathermap.org/data/2.5/weather?&q=kutahya
# Processing Record 333 | Malibu
# http://api.openweathermap.org/data/2.5/weather?&q=malibu
# Processing Record 334 | Terney
# http://api.openweathermap.org/data/2.5/weather?&q=terney
# Processing Record 335 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 336 | Ankang
# http://api.openweathermap.org/data/2.5/weather?&q=ankang
# Processing Record 337 | Baglan
# http://api.openweathermap.org/data/2.5/weather?&q=baglan
# Processing Record 338 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 339 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?&q=kimbe
# Processing Record 340 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 341 | Okha
# http://api.openweathermap.org/data/2.5/weather?&q=okha
# Processing Record 342 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# City not found
# Processing Record 343 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 344 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?&q=ugoofaaru
# City not found
# Processing Record 345 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 346 | San Jose de Rio Tinto
# http://api.openweathermap.org/data/2.5/weather?&q=san jose de rio tinto
# Processing Record 347 | Mpika
# http://api.openweathermap.org/data/2.5/weather?&q=mpika
# Processing Record 348 | Lasa
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 349 | Komarikhinskiy
# http://api.openweathermap.org/data/2.5/weather?&q=komarikhinskiy
# City not found
# City not found
# City not found
# Processing Record 350 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 351 | Moa
# http://api.openweathermap.org/data/2.5/weather?&q=moa
# Processing Record 352 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 353 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 354 | Victoria Point
# http://api.openweathermap.org/data/2.5/weather?&q=victoria point
# Processing Record 355 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# Processing Record 356 | Loksa
# http://api.openweathermap.org/data/2.5/weather?&q=loksa
# Processing Record 357 | Waitati
# http://api.openweathermap.org/data/2.5/weather?&q=waitati
# Processing Record 358 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 359 | Igarka
# http://api.openweathermap.org/data/2.5/weather?&q=igarka
# Processing Record 360 | Gouyave
# http://api.openweathermap.org/data/2.5/weather?&q=gouyave
# Processing Record 361 | Omaruru
# http://api.openweathermap.org/data/2.5/weather?&q=omaruru
# City not found
# Processing Record 362 | Gat
# http://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 363 | Salinas
# http://api.openweathermap.org/data/2.5/weather?&q=salinas
# Processing Record 364 | Darhan
# http://api.openweathermap.org/data/2.5/weather?&q=darhan
# Processing Record 365 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# Processing Record 366 | Fatehpur
# http://api.openweathermap.org/data/2.5/weather?&q=fatehpur
# Processing Record 367 | Mayo
# http://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 368 | Eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?&q=eyrarbakki
# Processing Record 369 | Manicore
# http://api.openweathermap.org/data/2.5/weather?&q=manicore
# City not found
# Processing Record 370 | Robe
# http://api.openweathermap.org/data/2.5/weather?&q=robe
# Processing Record 371 | Stantsionno-Oyashinskiy
# http://api.openweathermap.org/data/2.5/weather?&q=stantsionno-oyashinskiy
# Processing Record 372 | Semporna
# http://api.openweathermap.org/data/2.5/weather?&q=semporna
# Processing Record 373 | Miranda
# http://api.openweathermap.org/data/2.5/weather?&q=miranda
# Processing Record 374 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 375 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?&q=huarmey
# Processing Record 376 | Soe
# http://api.openweathermap.org/data/2.5/weather?&q=soe
# Processing Record 377 | Les Escoumins
# http://api.openweathermap.org/data/2.5/weather?&q=les escoumins
# Processing Record 378 | Tocopilla
# http://api.openweathermap.org/data/2.5/weather?&q=tocopilla
# Processing Record 379 | Eureka
# http://api.openweathermap.org/data/2.5/weather?&q=eureka
# Processing Record 380 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?&q=mareeba
# Processing Record 381 | Rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 382 | Helong
# http://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 383 | Key Biscayne
# http://api.openweathermap.org/data/2.5/weather?&q=key biscayne
# Processing Record 384 | Jardim
# http://api.openweathermap.org/data/2.5/weather?&q=jardim
# Processing Record 385 | Buin
# http://api.openweathermap.org/data/2.5/weather?&q=buin
# Processing Record 386 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?&q=erenhot
# Processing Record 387 | Palu
# http://api.openweathermap.org/data/2.5/weather?&q=palu
# Processing Record 388 | Lebedinyy
# http://api.openweathermap.org/data/2.5/weather?&q=lebedinyy
# Processing Record 389 | Itapetininga
# http://api.openweathermap.org/data/2.5/weather?&q=itapetininga
# Processing Record 390 | San Jose
# http://api.openweathermap.org/data/2.5/weather?&q=san jose
# Processing Record 391 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?&q=mitsamiouli
# City not found
# Processing Record 392 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?&q=umm lajj
# Processing Record 393 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 394 | Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 395 | Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 396 | Tandil
# http://api.openweathermap.org/data/2.5/weather?&q=tandil
# City not found
# Processing Record 397 | Diamantino
# http://api.openweathermap.org/data/2.5/weather?&q=diamantino
# Processing Record 398 | Evensk
# http://api.openweathermap.org/data/2.5/weather?&q=evensk
# Processing Record 399 | Matagami
# http://api.openweathermap.org/data/2.5/weather?&q=matagami
# City not found
# Processing Record 400 | Tautira
# http://api.openweathermap.org/data/2.5/weather?&q=tautira
# Processing Record 401 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 402 | Bustamante
# http://api.openweathermap.org/data/2.5/weather?&q=bustamante
# Processing Record 403 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 404 | Pandrup
# http://api.openweathermap.org/data/2.5/weather?&q=pandrup
# Processing Record 405 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?&q=ukiah
# Processing Record 406 | Jiangkou
# http://api.openweathermap.org/data/2.5/weather?&q=jiangkou
# Processing Record 407 | Soderhamn
# http://api.openweathermap.org/data/2.5/weather?&q=soderhamn
# Processing Record 408 | Cutervo
# http://api.openweathermap.org/data/2.5/weather?&q=cutervo
# Processing Record 409 | Marawi
# http://api.openweathermap.org/data/2.5/weather?&q=marawi
# Processing Record 410 | Newport
# http://api.openweathermap.org/data/2.5/weather?&q=newport
# Processing Record 411 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# City not found
# Processing Record 412 | Limbang
# http://api.openweathermap.org/data/2.5/weather?&q=limbang
# Processing Record 413 | Dukhovshchina
# http://api.openweathermap.org/data/2.5/weather?&q=dukhovshchina
# Processing Record 414 | Bedele
# http://api.openweathermap.org/data/2.5/weather?&q=bedele
# Processing Record 415 | Kathmandu
# http://api.openweathermap.org/data/2.5/weather?&q=kathmandu
# Processing Record 416 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?&q=turukhansk
# Processing Record 417 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?&q=virginia beach
# Processing Record 418 | Sabha
# http://api.openweathermap.org/data/2.5/weather?&q=sabha
# Processing Record 419 | Natal
# http://api.openweathermap.org/data/2.5/weather?&q=natal
# Processing Record 420 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?&q=leshukonskoye
# Processing Record 421 | Aparecida do Taboado
# http://api.openweathermap.org/data/2.5/weather?&q=aparecida do taboado
# Processing Record 422 | Patos
# http://api.openweathermap.org/data/2.5/weather?&q=patos
# Processing Record 423 | Ryotsu
# http://api.openweathermap.org/data/2.5/weather?&q=ryotsu
# City not found
# Processing Record 424 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 425 | Codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 426 | Okato
# http://api.openweathermap.org/data/2.5/weather?&q=okato
# Processing Record 427 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 428 | Soc Trang
# http://api.openweathermap.org/data/2.5/weather?&q=soc trang
# Processing Record 429 | Szod
# http://api.openweathermap.org/data/2.5/weather?&q=szod
# Processing Record 430 | Ningxiang
# http://api.openweathermap.org/data/2.5/weather?&q=ningxiang
# Processing Record 431 | Englehart
# http://api.openweathermap.org/data/2.5/weather?&q=englehart
# Processing Record 432 | San Carlos de Bariloche
# http://api.openweathermap.org/data/2.5/weather?&q=san carlos de bariloche
# Processing Record 433 | Vardo
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# Processing Record 434 | Manaure
# http://api.openweathermap.org/data/2.5/weather?&q=manaure
# Processing Record 435 | Shaowu
# http://api.openweathermap.org/data/2.5/weather?&q=shaowu
# Processing Record 436 | Malchin
# http://api.openweathermap.org/data/2.5/weather?&q=malchin
# Processing Record 437 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 438 | Amazar
# http://api.openweathermap.org/data/2.5/weather?&q=amazar
# Processing Record 439 | Otofuke
# http://api.openweathermap.org/data/2.5/weather?&q=otofuke
# Processing Record 440 | Luba
# http://api.openweathermap.org/data/2.5/weather?&q=luba
# Processing Record 441 | Mandera
# http://api.openweathermap.org/data/2.5/weather?&q=mandera
# Processing Record 442 | Wundanyi
# http://api.openweathermap.org/data/2.5/weather?&q=wundanyi
# Processing Record 443 | Olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# Processing Record 444 | Xuanhua
# http://api.openweathermap.org/data/2.5/weather?&q=xuanhua
# Processing Record 445 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 446 | Houma
# http://api.openweathermap.org/data/2.5/weather?&q=houma
# Processing Record 447 | Dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?&q=dhidhdhoo
# City not found
# Processing Record 448 | Gobabis
# http://api.openweathermap.org/data/2.5/weather?&q=gobabis
# Processing Record 449 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 450 | Umea
# http://api.openweathermap.org/data/2.5/weather?&q=umea
# Processing Record 451 | Plesetsk
# http://api.openweathermap.org/data/2.5/weather?&q=plesetsk
# City not found
# Processing Record 452 | Coromandel
# http://api.openweathermap.org/data/2.5/weather?&q=coromandel
# Processing Record 453 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 454 | Pascagoula
# http://api.openweathermap.org/data/2.5/weather?&q=pascagoula
# Processing Record 455 | Tabou
# http://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 456 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?&q=kaeo
# Processing Record 457 | Benguela
# http://api.openweathermap.org/data/2.5/weather?&q=benguela
# City not found
# Processing Record 458 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# City not found
# Processing Record 459 | Kasongo
# http://api.openweathermap.org/data/2.5/weather?&q=kasongo
# Processing Record 460 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?&q=almaznyy
# Processing Record 461 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 462 | Chiuza
# http://api.openweathermap.org/data/2.5/weather?&q=chiuza
# City not found
# Processing Record 463 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# City not found
# Processing Record 464 | Yashan
# http://api.openweathermap.org/data/2.5/weather?&q=yashan
# Processing Record 465 | Creel
# http://api.openweathermap.org/data/2.5/weather?&q=creel
# Processing Record 466 | Malangwa
# http://api.openweathermap.org/data/2.5/weather?&q=malangwa
# Processing Record 467 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 468 | Sabang
# http://api.openweathermap.org/data/2.5/weather?&q=sabang
# Processing Record 469 | Namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 470 | Cabo Rojo
# http://api.openweathermap.org/data/2.5/weather?&q=cabo rojo
# City not found
# Processing Record 471 | Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 472 | Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 473 | Verkhneye Kazanishche
# http://api.openweathermap.org/data/2.5/weather?&q=verkhneye kazanishche
# Processing Record 474 | Lovozero
# http://api.openweathermap.org/data/2.5/weather?&q=lovozero
# Processing Record 475 | Verkh-Usugli
# http://api.openweathermap.org/data/2.5/weather?&q=verkh-usugli
# Processing Record 476 | Balikpapan
# http://api.openweathermap.org/data/2.5/weather?&q=balikpapan
# Processing Record 477 | Najran
# http://api.openweathermap.org/data/2.5/weather?&q=najran
# Processing Record 478 | Jilib
# http://api.openweathermap.org/data/2.5/weather?&q=jilib
# Processing Record 479 | Aswan
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# Processing Record 480 | Valleyview
# http://api.openweathermap.org/data/2.5/weather?&q=valleyview
# Processing Record 481 | North Bend
# http://api.openweathermap.org/data/2.5/weather?&q=north bend
# Processing Record 482 | Sweetwater
# http://api.openweathermap.org/data/2.5/weather?&q=sweetwater
# City not found
# Processing Record 483 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?&q=inuvik
# Processing Record 484 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?&q=athabasca
# Processing Record 485 | Portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 486 | Nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?&q=nizhnevartovsk
# Processing Record 487 | Lamar
# http://api.openweathermap.org/data/2.5/weather?&q=lamar
# Processing Record 488 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?&q=puerto leguizamo
# Processing Record 489 | Union City
# http://api.openweathermap.org/data/2.5/weather?&q=union city
# City not found
# Processing Record 490 | Zhuhai
# http://api.openweathermap.org/data/2.5/weather?&q=zhuhai
# Processing Record 491 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?&q=tres arroyos
# Processing Record 492 | Tshikapa
# http://api.openweathermap.org/data/2.5/weather?&q=tshikapa
# Processing Record 493 | San Luis
# http://api.openweathermap.org/data/2.5/weather?&q=san luis
# Processing Record 494 | Jinchang
# http://api.openweathermap.org/data/2.5/weather?&q=jinchang
# Processing Record 495 | Dali
# http://api.openweathermap.org/data/2.5/weather?&q=dali
# Processing Record 496 | Makasar
# http://api.openweathermap.org/data/2.5/weather?&q=makasar
# Processing Record 497 | Toyooka
# http://api.openweathermap.org/data/2.5/weather?&q=toyooka
# Processing Record 498 | Baft
# http://api.openweathermap.org/data/2.5/weather?&q=baft
# Processing Record 499 | Sola
# http://api.openweathermap.org/data/2.5/weather?&q=sola
# Processing Record 500 | Cap-aux-Meules
# http://api.openweathermap.org/data/2.5/weather?&q=cap-aux-meules
# Processing Record 501 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy kuranakh
# Processing Record 502 | Tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 503 | Shitanjing
# http://api.openweathermap.org/data/2.5/weather?&q=shitanjing
# Processing Record 504 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?&q=puerto escondido
# Processing Record 505 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?&q=muzhi
# Processing Record 506 | Summerville
# http://api.openweathermap.org/data/2.5/weather?&q=summerville
# Processing Record 507 | Fez
# http://api.openweathermap.org/data/2.5/weather?&q=fez
# Processing Record 508 | Lubango
# http://api.openweathermap.org/data/2.5/weather?&q=lubango
# Processing Record 509 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 510 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 511 | Kitgum
# http://api.openweathermap.org/data/2.5/weather?&q=kitgum
# Processing Record 512 | Alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?&q=alekseyevsk
# Processing Record 513 | Oistins
# http://api.openweathermap.org/data/2.5/weather?&q=oistins
# Processing Record 514 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?&q=akdepe
# Processing Record 515 | Tavira
# http://api.openweathermap.org/data/2.5/weather?&q=tavira
# Processing Record 516 | Savonlinna
# http://api.openweathermap.org/data/2.5/weather?&q=savonlinna
# Processing Record 517 | Ilebo
# http://api.openweathermap.org/data/2.5/weather?&q=ilebo
# Processing Record 518 | Ankpa
# http://api.openweathermap.org/data/2.5/weather?&q=ankpa
# Processing Record 519 | Bartica
# http://api.openweathermap.org/data/2.5/weather?&q=bartica
# Processing Record 520 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 521 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 522 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?&q=isla mujeres
# Processing Record 523 | Basoko
# http://api.openweathermap.org/data/2.5/weather?&q=basoko
# Processing Record 524 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 525 | Huanren
# http://api.openweathermap.org/data/2.5/weather?&q=huanren
# Processing Record 526 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?&q=pitimbu
# Processing Record 527 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?&q=cap malheureux
# Processing Record 528 | Haizhou
# http://api.openweathermap.org/data/2.5/weather?&q=haizhou
# Processing Record 529 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?&q=solnechnyy
# Processing Record 530 | Nanfeng
# http://api.openweathermap.org/data/2.5/weather?&q=nanfeng
# Processing Record 531 | Port Antonio
# http://api.openweathermap.org/data/2.5/weather?&q=port antonio
# Processing Record 532 | Bakchar
# http://api.openweathermap.org/data/2.5/weather?&q=bakchar
# Processing Record 533 | Kaduqli
# http://api.openweathermap.org/data/2.5/weather?&q=kaduqli
# Processing Record 534 | Huilong
# http://api.openweathermap.org/data/2.5/weather?&q=huilong
# Processing Record 535 | Prado
# http://api.openweathermap.org/data/2.5/weather?&q=prado
# Processing Record 536 | Jaguaribe
# http://api.openweathermap.org/data/2.5/weather?&q=jaguaribe
# Processing Record 537 | Vila do Maio
# http://api.openweathermap.org/data/2.5/weather?&q=vila do maio
# Processing Record 538 | Hohhot
# http://api.openweathermap.org/data/2.5/weather?&q=hohhot
# Processing Record 539 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 540 | Stonewall
# http://api.openweathermap.org/data/2.5/weather?&q=stonewall
# Processing Record 541 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?&q=ulladulla
# Processing Record 542 | Bose
# http://api.openweathermap.org/data/2.5/weather?&q=bose
# Processing Record 543 | Fukue
# http://api.openweathermap.org/data/2.5/weather?&q=fukue
# Processing Record 544 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?&q=kamenka
# Processing Record 545 | Alacranes
# http://api.openweathermap.org/data/2.5/weather?&q=alacranes
# Processing Record 546 | Zimovniki
# http://api.openweathermap.org/data/2.5/weather?&q=zimovniki
# Processing Record 547 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 548 | Trenggalek
# http://api.openweathermap.org/data/2.5/weather?&q=trenggalek
# Processing Record 549 | Gold Coast
# http://api.openweathermap.org/data/2.5/weather?&q=gold coast
# Processing Record 550 | Sagone
# http://api.openweathermap.org/data/2.5/weather?&q=sagone
# Processing Record 551 | Todos Santos
# http://api.openweathermap.org/data/2.5/weather?&q=todos santos
# Processing Record 552 | Juneau
# http://api.openweathermap.org/data/2.5/weather?&q=juneau
# Processing Record 553 | Shemonaikha
# http://api.openweathermap.org/data/2.5/weather?&q=shemonaikha
# Processing Record 554 | Sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 555 | Kyabe
# http://api.openweathermap.org/data/2.5/weather?&q=kyabe
# Processing Record 556 | Kedougou
# http://api.openweathermap.org/data/2.5/weather?&q=kedougou
# Processing Record 557 | Wajima
# http://api.openweathermap.org/data/2.5/weather?&q=wajima
# Processing Record 558 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?&q=ketchikan
# Processing Record 559 | Chanthaburi
# http://api.openweathermap.org/data/2.5/weather?&q=chanthaburi
# Processing Record 560 | Ponferrada
# http://api.openweathermap.org/data/2.5/weather?&q=ponferrada
# Processing Record 561 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?&q=iracoubo
# Processing Record 562 | La Baule-Escoublac
# http://api.openweathermap.org/data/2.5/weather?&q=la baule-escoublac
# Processing Record 563 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?&q=savannah bight
# Processing Record 564 | Aviles
# http://api.openweathermap.org/data/2.5/weather?&q=aviles
# Processing Record 565 | Nokaneng
# http://api.openweathermap.org/data/2.5/weather?&q=nokaneng
# Processing Record 566 | Kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# Processing Record 567 | Lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 568 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 569 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# Processing Record 570 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 571 | Eskisehir
# http://api.openweathermap.org/data/2.5/weather?&q=eskisehir
# Processing Record 572 | Mulchen
# http://api.openweathermap.org/data/2.5/weather?&q=mulchen
# City not found
# Processing Record 573 | Port Keats
# http://api.openweathermap.org/data/2.5/weather?&q=port keats
# Processing Record 574 | Peniche
# http://api.openweathermap.org/data/2.5/weather?&q=peniche
# Processing Record 575 | Delray Beach
# http://api.openweathermap.org/data/2.5/weather?&q=delray beach
# Processing Record 576 | Balkanabat
# http://api.openweathermap.org/data/2.5/weather?&q=balkanabat
# Processing Record 577 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# City not found
# Processing Record 578 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 579 | Derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?&q=derzhavinsk
# Processing Record 580 | Lobito
# http://api.openweathermap.org/data/2.5/weather?&q=lobito
# Processing Record 581 | Chiriqui Grande
# http://api.openweathermap.org/data/2.5/weather?&q=chiriqui grande
# Processing Record 582 | Lwowek Slaski
# http://api.openweathermap.org/data/2.5/weather?&q=lwowek slaski
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary & add lists

weather_dict = {
                    "City": city_name,
                    "Cloudiness":cloudiness, 
                    "Country":country,
                    "Date":date, 
                    "Humidity": humidity,
                    "Lat":lat, 
                    "Lng":lng, 
                    "Max Temp": max_temp,
                    "Wind Speed":wind_speed
                 }

# Create a DataFrame
weather_df = pd.DataFrame(weather_dict)

# Export the city data into a .csv
weather_df.to_csv(output_data_file, index=False)

# Display Count
weather_df.count()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-dc44958f2f2e> in <module>
#      16
#      17 # Export the city data into a .csv
# ---> 18 weather_df.to_csv(output_data_file, index=False)
#      19
#      20 # Display Count
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %%
#Display Data set

weather_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build scatter splot for data type

plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", facecolors="teal", edgecolors="black", alpha=.5)

#Incorporate other graph properties

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (\u00b0F)")
dt = int(citydf.loc[0]["Date"])
wdate = time.strftime("%D", time.localtime(dt))
plt.title(f"City Latitutde vs. Max Temperature ({wdate})")
plt.grid(alpha=.5)

# Save the figure

plt.savefig("../output_images/Max_Temp_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", facecolors="steelblue", edgecolors="black", alpha=.5)

# Incorporate the other graph properties

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure

plt.savefig("../output_images/Humidity_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", facecolors="steelblue", edgecolors="black", alpha=.5)

# Incorporate the other graph properties

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure

plt.savefig("../output_images/Cloudiness_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type

plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", facecolors="steelblue", edgecolors="black", alpha=.5)

# Incorporate the other graph properties

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure

plt.savefig("../output_images/Wind_Speed_vs_Latitude.png")

# Show plot

plt.show()
